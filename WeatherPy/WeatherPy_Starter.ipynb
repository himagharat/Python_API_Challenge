# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\ghara\.conda\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\ghara\.conda\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/world_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 1

# instantiate the lists to hold the data for each city
city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities:    
        # assemble url and make API request
        print(f"Processing Record {count} of Set 1 | {city}.")
        count = count + 1
        
        target_url = ("http://api.openweathermap.org/data/2.5/weather?"
                      'appid={0}&q={1}').format(weather_api_key,city)
        try:
            # extract results
            response = requests.get(target_url).json()
            
            # add the city info to the lists             
            city_list.append(response['name'])
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])
            
        except:
            print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | atuona.
# Processing Record 2 of Set 1 | maarianhamina.
# Processing Record 3 of Set 1 | ushuaia.
# Processing Record 4 of Set 1 | bredasdorp.
# Processing Record 5 of Set 1 | kapaa.
# Processing Record 6 of Set 1 | nivala.
# Processing Record 7 of Set 1 | cheuskiny.
# City not found. Skipping...
# Processing Record 8 of Set 1 | attawapiskat.
# City not found. Skipping...
# Processing Record 9 of Set 1 | qaanaaq.
# Processing Record 10 of Set 1 | shimoda.
# Processing Record 11 of Set 1 | victoria.
# Processing Record 12 of Set 1 | hobart.
# Processing Record 13 of Set 1 | rikitea.
# Processing Record 14 of Set 1 | taltal.
# Processing Record 15 of Set 1 | waipawa.
# Processing Record 16 of Set 1 | komsomolskiy.
# Processing Record 17 of Set 1 | touros.
# Processing Record 18 of Set 1 | lolua.
# City not found. Skipping...
# Processing Record 19 of Set 1 | hilo.
# Processing Record 20 of Set 1 | muroto.
# Processing Record 21 of Set 1 | mar del plata.
# Processing Record 22 of Set 1 | sisimiut.
# Processing Record 23 of Set 1 | hervey bay.
# Processing Record 24 of Set 1 | castro.
# Processing Record 25 of Set 1 | san carlos de bariloche.
# Processing Record 26 of Set 1 | subang.
# Processing Record 27 of Set 1 | tasiilaq.
# Processing Record 28 of Set 1 | busselton.
# Processing Record 29 of Set 1 | camopi.
# Processing Record 30 of Set 1 | airai.
# Processing Record 31 of Set 1 | taolanaro.
# City not found. Skipping...
# Processing Record 32 of Set 1 | matata.
# Processing Record 33 of Set 1 | bluff.
# Processing Record 34 of Set 1 | iqaluit.
# Processing Record 35 of Set 1 | aybak.
# City not found. Skipping...
# Processing Record 36 of Set 1 | marcona.
# City not found. Skipping...
# Processing Record 37 of Set 1 | ancud.
# Processing Record 38 of Set 1 | vaini.
# Processing Record 39 of Set 1 | vanimo.
# Processing Record 40 of Set 1 | padilla.
# Processing Record 41 of Set 1 | new norfolk.
# Processing Record 42 of Set 1 | stephenville.
# Processing Record 43 of Set 1 | acari.
# Processing Record 44 of Set 1 | alice springs.
# Processing Record 45 of Set 1 | khatanga.
# Processing Record 46 of Set 1 | fort saint john.
# City not found. Skipping...
# Processing Record 47 of Set 1 | puerto escondido.
# Processing Record 48 of Set 1 | severo-kurilsk.
# Processing Record 49 of Set 1 | basay.
# Processing Record 50 of Set 1 | carnarvon.
# Processing Record 51 of Set 1 | hermanus.
# Processing Record 52 of Set 1 | ribeira grande.
# Processing Record 53 of Set 1 | aketi.
# Processing Record 54 of Set 1 | hithadhoo.
# Processing Record 55 of Set 1 | belushya guba.
# City not found. Skipping...
# Processing Record 56 of Set 1 | viedma.
# Processing Record 57 of Set 1 | upernavik.
# Processing Record 58 of Set 1 | chuy.
# Processing Record 59 of Set 1 | punta arenas.
# Processing Record 60 of Set 1 | mataura.
# Processing Record 61 of Set 1 | santa maria.
# Processing Record 62 of Set 1 | grand river south east.
# City not found. Skipping...
# Processing Record 63 of Set 1 | morondava.
# Processing Record 64 of Set 1 | provideniya.
# Processing Record 65 of Set 1 | nikolskoye.
# Processing Record 66 of Set 1 | pochutla.
# Processing Record 67 of Set 1 | jamestown.
# Processing Record 68 of Set 1 | latacunga.
# Processing Record 69 of Set 1 | bubaque.
# Processing Record 70 of Set 1 | meulaboh.
# Processing Record 71 of Set 1 | axim.
# Processing Record 72 of Set 1 | longyearbyen.
# Processing Record 73 of Set 1 | tiksi.
# Processing Record 74 of Set 1 | benguela.
# Processing Record 75 of Set 1 | kashi.
# Processing Record 76 of Set 1 | norman wells.
# Processing Record 77 of Set 1 | raudeberg.
# Processing Record 78 of Set 1 | bethel.
# Processing Record 79 of Set 1 | luderitz.
# Processing Record 80 of Set 1 | tahta.
# Processing Record 81 of Set 1 | bargal.
# City not found. Skipping...
# Processing Record 82 of Set 1 | haines junction.
# Processing Record 83 of Set 1 | pangnirtung.
# Processing Record 84 of Set 1 | kavieng.
# Processing Record 85 of Set 1 | cape town.
# Processing Record 86 of Set 1 | saleaula.
# City not found. Skipping...
# Processing Record 87 of Set 1 | saint george.
# Processing Record 88 of Set 1 | tezu.
# Processing Record 89 of Set 1 | thompson.
# Processing Record 90 of Set 1 | howell.
# Processing Record 91 of Set 1 | barrow.
# Processing Record 92 of Set 1 | tuatapere.
# Processing Record 93 of Set 1 | mount isa.
# Processing Record 94 of Set 1 | benghazi.
# Processing Record 95 of Set 1 | kibala.
# Processing Record 96 of Set 1 | imbituba.
# Processing Record 97 of Set 1 | minsk.
# Processing Record 98 of Set 1 | portland.
# Processing Record 99 of Set 1 | puerto ayora.
# Processing Record 100 of Set 1 | tilichiki.
# Processing Record 101 of Set 1 | vardo.
# Processing Record 102 of Set 1 | dikson.
# Processing Record 103 of Set 1 | chumikan.
# Processing Record 104 of Set 1 | talnakh.
# Processing Record 105 of Set 1 | tsihombe.
# City not found. Skipping...
# Processing Record 106 of Set 1 | albany.
# Processing Record 107 of Set 1 | faya.
# Processing Record 108 of Set 1 | ciudad guayana.
# Processing Record 109 of Set 1 | coralville.
# Processing Record 110 of Set 1 | san cristobal.
# Processing Record 111 of Set 1 | morant bay.
# Processing Record 112 of Set 1 | camacha.
# Processing Record 113 of Set 1 | kodiak.
# Processing Record 114 of Set 1 | sitka.
# Processing Record 115 of Set 1 | puerto baquerizo moreno.
# Processing Record 116 of Set 1 | georgetown.
# Processing Record 117 of Set 1 | comodoro rivadavia.
# Processing Record 118 of Set 1 | port elizabeth.
# Processing Record 119 of Set 1 | mount darwin.
# Processing Record 120 of Set 1 | varhaug.
# Processing Record 121 of Set 1 | makat.
# Processing Record 122 of Set 1 | bengkulu.
# Processing Record 123 of Set 1 | road town.
# Processing Record 124 of Set 1 | ngukurr.
# City not found. Skipping...
# Processing Record 125 of Set 1 | tuktoyaktuk.
# Processing Record 126 of Set 1 | paamiut.
# Processing Record 127 of Set 1 | olafsvik.
# Processing Record 128 of Set 1 | ilulissat.
# Processing Record 129 of Set 1 | kahului.
# Processing Record 130 of Set 1 | vao.
# Processing Record 131 of Set 1 | clyde river.
# Processing Record 132 of Set 1 | anadyr.
# Processing Record 133 of Set 1 | praia da vitoria.
# Processing Record 134 of Set 1 | pailon.
# Processing Record 135 of Set 1 | illoqqortoormiut.
# City not found. Skipping...
# Processing Record 136 of Set 1 | solnechnyy.
# Processing Record 137 of Set 1 | cayenne.
# Processing Record 138 of Set 1 | shubarkuduk.
# Processing Record 139 of Set 1 | raton.
# Processing Record 140 of Set 1 | esperance.
# Processing Record 141 of Set 1 | sioux lookout.
# Processing Record 142 of Set 1 | hami.
# Processing Record 143 of Set 1 | lashio.
# Processing Record 144 of Set 1 | rungata.
# City not found. Skipping...
# Processing Record 145 of Set 1 | high prairie.
# Processing Record 146 of Set 1 | vila velha.
# Processing Record 147 of Set 1 | magway.
# Processing Record 148 of Set 1 | quchan.
# Processing Record 149 of Set 1 | takaka.
# Processing Record 150 of Set 1 | san patricio.
# Processing Record 151 of Set 1 | bulgan.
# Processing Record 152 of Set 1 | kaitangata.
# Processing Record 153 of Set 1 | namibe.
# Processing Record 154 of Set 1 | healdsburg.
# Processing Record 155 of Set 1 | kuche.
# City not found. Skipping...
# Processing Record 156 of Set 1 | butaritari.
# Processing Record 157 of Set 1 | port alfred.
# Processing Record 158 of Set 1 | alofi.
# Processing Record 159 of Set 1 | pevek.
# Processing Record 160 of Set 1 | rocha.
# Processing Record 161 of Set 1 | champerico.
# Processing Record 162 of Set 1 | yellowknife.
# Processing Record 163 of Set 1 | katsuura.
# Processing Record 164 of Set 1 | teguldet.
# Processing Record 165 of Set 1 | sun valley.
# Processing Record 166 of Set 1 | krasnoarmeysk.
# Processing Record 167 of Set 1 | valley city.
# Processing Record 168 of Set 1 | louisbourg.
# City not found. Skipping...
# Processing Record 169 of Set 1 | cedar city.
# Processing Record 170 of Set 1 | fortuna.
# Processing Record 171 of Set 1 | chebarkul.
# Processing Record 172 of Set 1 | takoradi.
# Processing Record 173 of Set 1 | palizada.
# Processing Record 174 of Set 1 | torbay.
# Processing Record 175 of Set 1 | atar.
# Processing Record 176 of Set 1 | hualmay.
# Processing Record 177 of Set 1 | prince albert.
# Processing Record 178 of Set 1 | saint-augustin.
# Processing Record 179 of Set 1 | coihaique.
# Processing Record 180 of Set 1 | barra do garcas.
# Processing Record 181 of Set 1 | arraial do cabo.
# Processing Record 182 of Set 1 | swan hill.
# Processing Record 183 of Set 1 | mogadishu.
# Processing Record 184 of Set 1 | pedernales.
# Processing Record 185 of Set 1 | bairiki.
# Processing Record 186 of Set 1 | khuzhir.
# Processing Record 187 of Set 1 | rawah.
# Processing Record 188 of Set 1 | dicabisagan.
# Processing Record 189 of Set 1 | geraldton.
# Processing Record 190 of Set 1 | kamaishi.
# Processing Record 191 of Set 1 | tarauaca.
# Processing Record 192 of Set 1 | sur.
# Processing Record 193 of Set 1 | te anau.
# Processing Record 194 of Set 1 | leningradskiy.
# Processing Record 195 of Set 1 | saskylakh.
# Processing Record 196 of Set 1 | bardiyah.
# Processing Record 197 of Set 1 | hearst.
# Processing Record 198 of Set 1 | bandarbeyla.
# Processing Record 199 of Set 1 | fairbanks.
# Processing Record 200 of Set 1 | novokizhinginsk.
# Processing Record 201 of Set 1 | gamba.
# Processing Record 202 of Set 1 | yomitan.
# City not found. Skipping...
# Processing Record 203 of Set 1 | amderma.
# City not found. Skipping...
# Processing Record 204 of Set 1 | klaksvik.
# Processing Record 205 of Set 1 | margate.
# Processing Record 206 of Set 1 | cherskiy.
# Processing Record 207 of Set 1 | tual.
# Processing Record 208 of Set 1 | chapais.
# Processing Record 209 of Set 1 | mahebourg.
# Processing Record 210 of Set 1 | khandyga.
# Processing Record 211 of Set 1 | pemba.
# Processing Record 212 of Set 1 | sistranda.
# Processing Record 213 of Set 1 | chokurdakh.
# Processing Record 214 of Set 1 | bonavista.
# Processing Record 215 of Set 1 | biak.
# Processing Record 216 of Set 1 | boyolangu.
# Processing Record 217 of Set 1 | bathsheba.
# Processing Record 218 of Set 1 | peterborough.
# Processing Record 219 of Set 1 | homer.
# Processing Record 220 of Set 1 | ust-nera.
# Processing Record 221 of Set 1 | malakwal.
# Processing Record 222 of Set 1 | west bay.
# Processing Record 223 of Set 1 | spoltore.
# Processing Record 224 of Set 1 | cidreira.
# Processing Record 225 of Set 1 | nelson.
# Processing Record 226 of Set 1 | maceio.
# Processing Record 227 of Set 1 | east london.
# Processing Record 228 of Set 1 | okahandja.
# Processing Record 229 of Set 1 | izhmorskiy.
# Processing Record 230 of Set 1 | nidzica.
# Processing Record 231 of Set 1 | eureka.
# Processing Record 232 of Set 1 | bayir.
# Processing Record 233 of Set 1 | kununurra.
# Processing Record 234 of Set 1 | barentsburg.
# City not found. Skipping...
# Processing Record 235 of Set 1 | praxedis guerrero.
# Processing Record 236 of Set 1 | port keats.
# Processing Record 237 of Set 1 | kieta.
# Processing Record 238 of Set 1 | key largo.
# Processing Record 239 of Set 1 | qasigiannguit.
# Processing Record 240 of Set 1 | sentyabrskiy.
# City not found. Skipping...
# Processing Record 241 of Set 1 | vreed en hoop.
# City not found. Skipping...
# Processing Record 242 of Set 1 | sabha.
# Processing Record 243 of Set 1 | vanavara.
# Processing Record 244 of Set 1 | necochea.
# Processing Record 245 of Set 1 | saint-philippe.
# Processing Record 246 of Set 1 | mys shmidta.
# City not found. Skipping...
# Processing Record 247 of Set 1 | constantine.
# Processing Record 248 of Set 1 | ugoofaaru.
# Processing Record 249 of Set 1 | agva.
# City not found. Skipping...
# Processing Record 250 of Set 1 | gardner.
# Processing Record 251 of Set 1 | krasnogvardeyskoye.
# Processing Record 252 of Set 1 | kannur.
# Processing Record 253 of Set 1 | raga.
# Processing Record 254 of Set 1 | savinka.
# Processing Record 255 of Set 1 | fort nelson.
# Processing Record 256 of Set 1 | bangassou.
# Processing Record 257 of Set 1 | traverse city.
# Processing Record 258 of Set 1 | vitim.
# Processing Record 259 of Set 1 | thunder bay.
# Processing Record 260 of Set 1 | kilmez.
# City not found. Skipping...
# Processing Record 261 of Set 1 | kutum.
# Processing Record 262 of Set 1 | bambous virieux.
# Processing Record 263 of Set 1 | aklavik.
# Processing Record 264 of Set 1 | lebu.
# Processing Record 265 of Set 1 | kattivakkam.
# Processing Record 266 of Set 1 | hamilton.
# Processing Record 267 of Set 1 | kadoma.
# Processing Record 268 of Set 1 | ponta do sol.
# Processing Record 269 of Set 1 | asfi.
# Processing Record 270 of Set 1 | bratsk.
# Processing Record 271 of Set 1 | aksha.
# Processing Record 272 of Set 1 | ypsonas.
# Processing Record 273 of Set 1 | la ronge.
# Processing Record 274 of Set 1 | saiha.
# Processing Record 275 of Set 1 | khasan.
# Processing Record 276 of Set 1 | brownwood.
# Processing Record 277 of Set 1 | sokolo.
# Processing Record 278 of Set 1 | caravelas.
# Processing Record 279 of Set 1 | carayao.
# Processing Record 280 of Set 1 | ust-tsilma.
# Processing Record 281 of Set 1 | chunskiy.
# Processing Record 282 of Set 1 | yulara.
# Processing Record 283 of Set 1 | lompoc.
# Processing Record 284 of Set 1 | sidi ali.
# Processing Record 285 of Set 1 | miri.
# Processing Record 286 of Set 1 | chara.
# Processing Record 287 of Set 1 | hrodna.
# Processing Record 288 of Set 1 | olinda.
# Processing Record 289 of Set 1 | yenagoa.
# Processing Record 290 of Set 1 | gat.
# Processing Record 291 of Set 1 | kloulklubed.
# Processing Record 292 of Set 1 | mildura.
# Processing Record 293 of Set 1 | nuristan.
# Processing Record 294 of Set 1 | neuquen.
# Processing Record 295 of Set 1 | gornyy.
# Processing Record 296 of Set 1 | birjand.
# Processing Record 297 of Set 1 | arandis.
# Processing Record 298 of Set 1 | vernon.
# Processing Record 299 of Set 1 | ambilobe.
# Processing Record 300 of Set 1 | buala.
# Processing Record 301 of Set 1 | vaitupu.
# City not found. Skipping...
# Processing Record 302 of Set 1 | ahipara.
# Processing Record 303 of Set 1 | quatre cocos.
# Processing Record 304 of Set 1 | doctor pedro p. pena.
# City not found. Skipping...
# Processing Record 305 of Set 1 | cruzeiro.
# Processing Record 306 of Set 1 | channel-port aux basques.
# Processing Record 307 of Set 1 | bam.
# Processing Record 308 of Set 1 | nome.
# Processing Record 309 of Set 1 | cabo san lucas.
# Processing Record 310 of Set 1 | maicao.
# Processing Record 311 of Set 1 | sirfa.
# City not found. Skipping...
# Processing Record 312 of Set 1 | shingu.
# Processing Record 313 of Set 1 | egvekinot.
# Processing Record 314 of Set 1 | zeerust.
# Processing Record 315 of Set 1 | kyra.
# Processing Record 316 of Set 1 | diamantino.
# Processing Record 317 of Set 1 | pyinmana.
# Processing Record 318 of Set 1 | bourail.
# Processing Record 319 of Set 1 | calbuco.
# Processing Record 320 of Set 1 | salalah.
# Processing Record 321 of Set 1 | makakilo city.
# Processing Record 322 of Set 1 | bireun.
# Processing Record 323 of Set 1 | mitu.
# Processing Record 324 of Set 1 | aquin.
# Processing Record 325 of Set 1 | burica.
# City not found. Skipping...
# Processing Record 326 of Set 1 | the valley.
# Processing Record 327 of Set 1 | payo.
# Processing Record 328 of Set 1 | yashalta.
# Processing Record 329 of Set 1 | nemuro.
# Processing Record 330 of Set 1 | lagoa.
# Processing Record 331 of Set 1 | saldanha.
# Processing Record 332 of Set 1 | dabola.
# Processing Record 333 of Set 1 | killini.
# City not found. Skipping...
# Processing Record 334 of Set 1 | dalianwan.
# Processing Record 335 of Set 1 | belmonte.
# Processing Record 336 of Set 1 | narsaq.
# Processing Record 337 of Set 1 | avera.
# Processing Record 338 of Set 1 | beyneu.
# Processing Record 339 of Set 1 | veraval.
# Processing Record 340 of Set 1 | balkanabat.
# Processing Record 341 of Set 1 | abonnema.
# Processing Record 342 of Set 1 | salinas.
# Processing Record 343 of Set 1 | bealanana.
# Processing Record 344 of Set 1 | cabra.
# Processing Record 345 of Set 1 | ratnagiri.
# Processing Record 346 of Set 1 | mendi.
# Processing Record 347 of Set 1 | zhaocheng.
# City not found. Skipping...
# Processing Record 348 of Set 1 | bon accord.
# Processing Record 349 of Set 1 | avezzano.
# Processing Record 350 of Set 1 | zhuhai.
# Processing Record 351 of Set 1 | hasaki.
# Processing Record 352 of Set 1 | yamada.
# Processing Record 353 of Set 1 | gimli.
# Processing Record 354 of Set 1 | tiarei.
# Processing Record 355 of Set 1 | kungurtug.
# Processing Record 356 of Set 1 | bonnyville.
# Processing Record 357 of Set 1 | milingimbi.
# City not found. Skipping...
# Processing Record 358 of Set 1 | nizwa.
# Processing Record 359 of Set 1 | tura.
# Processing Record 360 of Set 1 | lavrentiya.
# Processing Record 361 of Set 1 | avarua.
# Processing Record 362 of Set 1 | goure.
# Processing Record 363 of Set 1 | yagodnoye.
# Processing Record 364 of Set 1 | katangi.
# Processing Record 365 of Set 1 | seymchan.
# Processing Record 366 of Set 1 | sechura.
# Processing Record 367 of Set 1 | guerrero negro.
# Processing Record 368 of Set 1 | rebrikha.
# Processing Record 369 of Set 1 | srednekolymsk.
# Processing Record 370 of Set 1 | sampit.
# Processing Record 371 of Set 1 | isangel.
# Processing Record 372 of Set 1 | gloversville.
# Processing Record 373 of Set 1 | broken hill.
# Processing Record 374 of Set 1 | ketchikan.
# Processing Record 375 of Set 1 | haiger.
# Processing Record 376 of Set 1 | karratha.
# Processing Record 377 of Set 1 | bridlington.
# Processing Record 378 of Set 1 | boksitogorsk.
# Processing Record 379 of Set 1 | praya.
# Processing Record 380 of Set 1 | stanislav.
# Processing Record 381 of Set 1 | vestmannaeyjar.
# Processing Record 382 of Set 1 | greve strand.
# Processing Record 383 of Set 1 | galiwinku.
# City not found. Skipping...
# Processing Record 384 of Set 1 | acapulco.
# Processing Record 385 of Set 1 | reconquista.
# Processing Record 386 of Set 1 | plettenberg bay.
# Processing Record 387 of Set 1 | hofn.
# Processing Record 388 of Set 1 | sangar.
# Processing Record 389 of Set 1 | broome.
# Processing Record 390 of Set 1 | vuktyl.
# Processing Record 391 of Set 1 | muli.
# Processing Record 392 of Set 1 | ambodifototra.
# City not found. Skipping...
# Processing Record 393 of Set 1 | copiapo.
# Processing Record 394 of Set 1 | sabaudia.
# Processing Record 395 of Set 1 | nouadhibou.
# Processing Record 396 of Set 1 | trojes.
# Processing Record 397 of Set 1 | yar-sale.
# Processing Record 398 of Set 1 | najran.
# Processing Record 399 of Set 1 | umm kaddadah.
# Processing Record 400 of Set 1 | darhan.
# Processing Record 401 of Set 1 | bilma.
# Processing Record 402 of Set 1 | asau.
# Processing Record 403 of Set 1 | matara.
# Processing Record 404 of Set 1 | gornopravdinsk.
# Processing Record 405 of Set 1 | nyrob.
# Processing Record 406 of Set 1 | kamiiso.
# Processing Record 407 of Set 1 | naze.
# Processing Record 408 of Set 1 | tevaitoa.
# Processing Record 409 of Set 1 | sakhnovshchyna.
# Processing Record 410 of Set 1 | les cayes.
# Processing Record 411 of Set 1 | codrington.
# Processing Record 412 of Set 1 | westport.
# Processing Record 413 of Set 1 | laguna.
# Processing Record 414 of Set 1 | samarai.
# Processing Record 415 of Set 1 | bundaberg.
# Processing Record 416 of Set 1 | riachao das neves.
# Processing Record 417 of Set 1 | porto velho.
# Processing Record 418 of Set 1 | sao gabriel da cachoeira.
# Processing Record 419 of Set 1 | hihifo.
# City not found. Skipping...
# Processing Record 420 of Set 1 | westerly.
# Processing Record 421 of Set 1 | bac lieu.
# Processing Record 422 of Set 1 | ati.
# Processing Record 423 of Set 1 | san luis.
# Processing Record 424 of Set 1 | poum.
# Processing Record 425 of Set 1 | praia.
# Processing Record 426 of Set 1 | coahuayana.
# Processing Record 427 of Set 1 | grand bank.
# Processing Record 428 of Set 1 | xuddur.
# Processing Record 429 of Set 1 | zhangye.
# Processing Record 430 of Set 1 | tidore.
# City not found. Skipping...
# Processing Record 431 of Set 1 | newport.
# Processing Record 432 of Set 1 | sorland.
# Processing Record 433 of Set 1 | okha.
# Processing Record 434 of Set 1 | malakal.
# Processing Record 435 of Set 1 | vieques.
# Processing Record 436 of Set 1 | monster.
# Processing Record 437 of Set 1 | suchiapa.
# Processing Record 438 of Set 1 | sao jose da coroa grande.
# Processing Record 439 of Set 1 | goderich.
# Processing Record 440 of Set 1 | san vicente.
# Processing Record 441 of Set 1 | taraza.
# Processing Record 442 of Set 1 | regenstauf.
# Processing Record 443 of Set 1 | qaqortoq.
# Processing Record 444 of Set 1 | aasiaat.
# Processing Record 445 of Set 1 | grand gaube.
# Processing Record 446 of Set 1 | pyu.
# Processing Record 447 of Set 1 | zhigansk.
# Processing Record 448 of Set 1 | ronne.
# Processing Record 449 of Set 1 | sawtell.
# Processing Record 450 of Set 1 | verkhnyaya inta.
# Processing Record 451 of Set 1 | otukpo.
# Processing Record 452 of Set 1 | peachland.
# Processing Record 453 of Set 1 | male.
# Processing Record 454 of Set 1 | vondrozo.
# Processing Record 455 of Set 1 | pilar.
# Processing Record 456 of Set 1 | kousseri.
# Processing Record 457 of Set 1 | okmulgee.
# Processing Record 458 of Set 1 | richards bay.
# Processing Record 459 of Set 1 | ajdabiya.
# Processing Record 460 of Set 1 | greenwood.
# Processing Record 461 of Set 1 | marbella.
# Processing Record 462 of Set 1 | port-de-paix.
# City not found. Skipping...
# Processing Record 463 of Set 1 | kargasok.
# Processing Record 464 of Set 1 | pozega.
# Processing Record 465 of Set 1 | shibganj.
# Processing Record 466 of Set 1 | oktyabrskiy.
# Processing Record 467 of Set 1 | svetlaya.
# Processing Record 468 of Set 1 | viking.
# Processing Record 469 of Set 1 | karaton.
# Processing Record 470 of Set 1 | thabazimbi.
# Processing Record 471 of Set 1 | nhulunbuy.
# Processing Record 472 of Set 1 | aykhal.
# Processing Record 473 of Set 1 | tonj.
# Processing Record 474 of Set 1 | mendoza.
# Processing Record 475 of Set 1 | karaul.
# City not found. Skipping...
# Processing Record 476 of Set 1 | kysyl-syr.
# Processing Record 477 of Set 1 | teya.
# Processing Record 478 of Set 1 | juxtlahuaca.
# Processing Record 479 of Set 1 | sao filipe.
# Processing Record 480 of Set 1 | rogun.
# City not found. Skipping...
# Processing Record 481 of Set 1 | hit.
# Processing Record 482 of Set 1 | soc trang.
# Processing Record 483 of Set 1 | shalakusha.
# Processing Record 484 of Set 1 | dingle.
# Processing Record 485 of Set 1 | nalut.
# Processing Record 486 of Set 1 | ostrovnoy.
# Processing Record 487 of Set 1 | deputatskiy.
# Processing Record 488 of Set 1 | ho.
# City not found. Skipping...
# Processing Record 489 of Set 1 | nizhneyansk.
# City not found. Skipping...
# Processing Record 490 of Set 1 | penzance.
# Processing Record 491 of Set 1 | sao joao da barra.
# Processing Record 492 of Set 1 | boyabat.
# Processing Record 493 of Set 1 | cap malheureux.
# Processing Record 494 of Set 1 | waitati.
# Processing Record 495 of Set 1 | umtata.
# Processing Record 496 of Set 1 | basco.
# Processing Record 497 of Set 1 | flinders.
# Processing Record 498 of Set 1 | college.
# Processing Record 499 of Set 1 | beloha.
# Processing Record 500 of Set 1 | manzil tamim.
# City not found. Skipping...
# Processing Record 501 of Set 1 | harper.
# Processing Record 502 of Set 1 | batemans bay.
# Processing Record 503 of Set 1 | ayan.
# Processing Record 504 of Set 1 | mount gambier.
# Processing Record 505 of Set 1 | carmelo.
# Processing Record 506 of Set 1 | itumbiara.
# Processing Record 507 of Set 1 | ukiah.
# Processing Record 508 of Set 1 | bedesa.
# Processing Record 509 of Set 1 | pisco.
# Processing Record 510 of Set 1 | zolotinka.
# City not found. Skipping...
# Processing Record 511 of Set 1 | amparafaravola.
# Processing Record 512 of Set 1 | meridian.
# Processing Record 513 of Set 1 | viet tri.
# Processing Record 514 of Set 1 | dudinka.
# Processing Record 515 of Set 1 | jingdezhen.
# Processing Record 516 of Set 1 | adrar.
# Processing Record 517 of Set 1 | prosyana.
# City not found. Skipping...
# Processing Record 518 of Set 1 | trat.
# Processing Record 519 of Set 1 | acarau.
# Processing Record 520 of Set 1 | tayga.
# Processing Record 521 of Set 1 | riviere-au-renard.
# Processing Record 522 of Set 1 | tooele.
# Processing Record 523 of Set 1 | tautira.
# Processing Record 524 of Set 1 | warri.
# Processing Record 525 of Set 1 | buin.
# Processing Record 526 of Set 1 | lakatoro.
# Processing Record 527 of Set 1 | houma.
# Processing Record 528 of Set 1 | canarana.
# Processing Record 529 of Set 1 | burkhala.
# City not found. Skipping...
# Processing Record 530 of Set 1 | aksarka.
# Processing Record 531 of Set 1 | vila franca do campo.
# Processing Record 532 of Set 1 | marawi.
# Processing Record 533 of Set 1 | uspenskaya.
# Processing Record 534 of Set 1 | pangkalanbuun.
# Processing Record 535 of Set 1 | dillon.
# Processing Record 536 of Set 1 | forbes.
# Processing Record 537 of Set 1 | mariental.
# Processing Record 538 of Set 1 | garissa.
# Processing Record 539 of Set 1 | kruisfontein.
# Processing Record 540 of Set 1 | okhotsk.
# Processing Record 541 of Set 1 | tuggurt.
# City not found. Skipping...
# Processing Record 542 of Set 1 | lata.
# Processing Record 543 of Set 1 | lasa.
# Processing Record 544 of Set 1 | roanoke rapids.
# Processing Record 545 of Set 1 | port lincoln.
# Processing Record 546 of Set 1 | bayeux.
# Processing Record 547 of Set 1 | lensk.
# Processing Record 548 of Set 1 | nalobikha.
# Processing Record 549 of Set 1 | muana.
# Processing Record 550 of Set 1 | paraiso.
# Processing Record 551 of Set 1 | beringovskiy.
# Processing Record 552 of Set 1 | gravdal.
# Processing Record 553 of Set 1 | roma.
# Processing Record 554 of Set 1 | mantua.
# Processing Record 555 of Set 1 | afmadu.
# City not found. Skipping...
# Processing Record 556 of Set 1 | yantal.
# Processing Record 557 of Set 1 | hauterive.
# Processing Record 558 of Set 1 | yirol.
# City not found. Skipping...
# Processing Record 559 of Set 1 | port blair.
# Processing Record 560 of Set 1 | dawei.
# Processing Record 561 of Set 1 | matagami.
# Processing Record 562 of Set 1 | shache.
# Processing Record 563 of Set 1 | aksu.
# Processing Record 564 of Set 1 | smithers.
# Processing Record 565 of Set 1 | ngorongoro.
# Processing Record 566 of Set 1 | makarov.
# Processing Record 567 of Set 1 | ballina.
# Processing Record 568 of Set 1 | manaus.
# Processing Record 569 of Set 1 | balti.
# Processing Record 570 of Set 1 | santa fe.
# Processing Record 571 of Set 1 | otradnoye.
# Processing Record 572 of Set 1 | klyuchi.
# Processing Record 573 of Set 1 | souillac.
# Processing Record 574 of Set 1 | guaruja.
# Processing Record 575 of Set 1 | hudson bay.
# Processing Record 576 of Set 1 | puerto madryn.
# Processing Record 577 of Set 1 | bokoro.
# Processing Record 578 of Set 1 | sergeyevka.
# Processing Record 579 of Set 1 | kabanjahe.
# Processing Record 580 of Set 1 | hirara.
# Processing Record 581 of Set 1 | mpwapwa.
# Processing Record 582 of Set 1 | el jicaro.
# Processing Record 583 of Set 1 | sungaipenuh.
# Processing Record 584 of Set 1 | itarema.
# Processing Record 585 of Set 1 | udachnyy.
# Processing Record 586 of Set 1 | gold coast.
# Processing Record 587 of Set 1 | burgeo.
# Processing Record 588 of Set 1 | palana.
# Processing Record 589 of Set 1 | remanso.
# Processing Record 590 of Set 1 | korla.
# Processing Record 591 of Set 1 | brae.
# Processing Record 592 of Set 1 | ola.
# Processing Record 593 of Set 1 | serenje.
# Processing Record 594 of Set 1 | constitucion.
# Processing Record 595 of Set 1 | safaqis.
# City not found. Skipping...
# Processing Record 596 of Set 1 | salair.
# Processing Record 597 of Set 1 | chlorakas.
# Processing Record 598 of Set 1 | luanda.
# Processing Record 599 of Set 1 | moron.
# Processing Record 600 of Set 1 | okato.
# Processing Record 601 of Set 1 | esfarayen.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# convert the max temp to F from Kelvin
max_temp = [(9/5)*(x - 273) + 32 for x in max_temp]

# populate the dataframe with the city info
city_df = pd.DataFrame({
                            "City":city_list,
                            "Cloudiness":cloudiness,
                            "Country":country,
                            "Date":date,
                            "Humidity":humidity,
                            "Lat":lat,
                            "Lng":lng,
                            "Max Temp":max_temp,
                            "Wind Speed":wind_speed
    
})

# write the dataframe to a csv
city_df.to_csv("world_cities.csv")
city_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Atuona          12      PF  1604180847        75  -9.80 -139.03
# 1   Mariehamn          90      AX  1604180847        93  60.10   19.93
# 2     Ushuaia          90      AR  1604180769        93 -54.80  -68.30
# 3  Bredasdorp           0      ZA  1604180847        82 -34.53   20.04
# 4       Kapaa          40      US  1604180847        66  22.08 -159.32
#
#    Max Temp  Wind Speed
# 0     78.80        7.68
# 1     50.27        6.20
# 2     50.27        4.10
# 3     57.47        2.10
# 4     84.47        5.70

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No Cities with humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature')
ax.scatter(city_df['Lat'],city_df['Max Temp'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(city_df['Lat'],city_df['Humidity'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(city_df['Lat'],city_df['Cloudiness'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(city_df['Lat'],city_df['Wind Speed'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_wind_speed.png')

# %% [markdown]
# ## Linear Regression

# %%
x_val=north_hem["Latitude"]
y_val=north_hem["Temperature"]
(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val,y_val)
regress_val=x_val*slope+intercept
line_eq="y="+str(round(slope,2))+"x+"+str(round(intercept,2))
plt.scatter(x_val,y_val)
plt.plot(x_val,regress_val,"r-")
plt.annotate(line_eq,(-50,80),color="red")
plt.title("North Hemisphere: Latitude v Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
print(f"rvalue={round(rvalue,2)}")
plt.savefig("../Images/north_hem_temp.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6ce52c5a17e2> in <module>
# ----> 1 x_val=north_hem["Latitude"]
#       2 y_val=north_hem["Temperature"]
#       3 (slope, intercept, rvalue, pvalue, stderr)=linregress(x_val,y_val)
#       4 regress_val=x_val*slope+intercept
#       5 line_eq="y="+str(round(slope,2))+"x+"+str(round(intercept,2))
#
# NameError: name 'north_hem' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
